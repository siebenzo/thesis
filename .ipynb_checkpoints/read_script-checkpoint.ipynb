# %%
import cv2
import urllib.request
import requests
import numpy as np
import socket
from datetime import datetime
import pandas as pd
import time
import http.client

http.client._MAXHEADERS = 1000


#http_request_ON = False
#socket_ON = True

http_request_ON = True
socket_ON = False

# Load the face detection model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Define the ESP32 Wrover's IP address and port number
url = 'http://10.0.0.15:81'

arr_socket = np.array([])
arr_http = np.array([])
arr_read_vs_detect = np.array([])
av = pd.DataFrame({})
df = pd.DataFrame({})

# Open the video stream from the ESP32 Wrover
stream = urllib.request.urlopen(url)

cv2.namedWindow('Video Stream', cv2.WINDOW_NORMAL)

# Loop through the frames in the video stream, time stamp nog toevoegen begin read en face detected

while True:
    # Read the next frame from the video stream
    buffer = bytes()
    #set timestamp start reading
    dt = datetime.now()
    ts_data = datetime.timestamp(dt)
    while True:
        try:            
            buffer += stream.read(2500)
            #buffer += stream.read(10000)
        except http.client.IncompleteRead:
            print("IncompleteRead error occurred, retrying...")
            continue
    
        a = buffer.find(b'\xff\xd8')
        b = buffer.find(b'\xff\xd9')
        
        
        #print(a, b)
        if a != -1 and b != -1:
            break
        elif a != -1 and b == -1:
            buffer = buffer[a:]
            break
    
    if a != -1 and b != -1 and b > a:
        #print(a,b)
        frame = cv2.imdecode(np.frombuffer(buffer[a:b+2], dtype=np.uint8), cv2.IMREAD_COLOR)

        if frame is not None:
            cv2.imshow('Video Stream', frame)

            # Apply the face detection model to the frame
            faces = face_cascade.detectMultiScale(frame, scaleFactor=1.1, minNeighbors=5)
            
            # Draw bounding boxes around the detected faces
            for (x, y, w, h) in faces:
                cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
                
                #SET TIMESTAMP, FACE DETECTED
                dt = datetime.now()
                ts_detect = datetime.timestamp(dt)
                
                #print("FACE DETECTED ON:", ts_detect)
                
                # Define the ESP32's IP address and port number
                ip = "10.0.0.15"
                port = 81
    
                #print("I see you!")

                # Define the integer to send
                message = 3
                
                if http_request_ON == True :
                    # Send number 32 to ESP32 over WiFi
                    print("sending data over http_request!")
                    #requests.get('http://10.0.0.15/?data=3')
                    try:
                        response = requests.get('http://10.0.0.15/?data=3', timeout=1)
                    except requests.Timeout:
                        print("Request timed out")
        
                    #SET TIMESTAMP HTTP_REQUEST
                    dt = datetime.now()
                    ts_HTTP_REQUEST_data = datetime.timestamp(dt)
                    print("DATA SEND VIA HTTP_REQUEST ON:", ts_HTTP_REQUEST_data)
                    
                    diff_data_HTTPREQUEST =  ts_HTTP_REQUEST_data -ts_detect
                    #if statement groter dan 1 sec niet gebruiken in array.
                    if(diff_data_HTTPREQUEST  < 1):
                        arr_http = np.insert(arr_http, 0, [diff_data_HTTPREQUEST * 1000])
                        #print(arr_http)
                        arr_avg = np.array([])
                        arr_avg = np.insert(arr_avg, 0, [np.average(arr_http)])
                        print("the average of the array is: " , np.average(arr_http) , "(filtered outliers)")
                    print("TIME DIFFERENCE HTTP REQUEST:" , diff_data_HTTPREQUEST * 1000 , "ms") 
                    ts_detect_data = ts_detect - ts_data
                    arr_read_vs_detect = np.insert(arr_read_vs_detect, 0, ts_detect_data*1000)
                    print("TIME DIFFERENCE READING IN DATA VS DETECTING FACE" , ts_detect_data*1000)
                    print("the average time between detect and send is: " , np.average(arr_read_vs_detect), " ms")
                    
                #define staat bovenaan! 
                if socket_ON == True :
                    # Create a socket object
                    #print("sending data over socket!")
                    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

                    # Connect to the ESP32
                    #print("connecting so ESP32")
                    client_socket.connect((ip, port))

                    # Send the integer as a string
                    #print("sending message as a string")
                    client_socket.send(str(message).encode())
                
                    #SET TIMESTAMP SOCKET
                    dt = datetime.now()
                    ts_socket_data = datetime.timestamp(dt)
                    #print("DATA SEND VIA SOCKET ON:", ts_socket_data)

                    # Close the socket connection
                    client_socket.close()
                    
                    diff_data_socket = ts_socket_data - ts_detect
                    if(diff_data_socket  < 1):
                        arr_socket = np.insert(arr_socket, 0, [diff_data_socket * 1000])
                        #print(arr_socket)
                        arr_avg = np.array([])
                        arr_avg = np.insert(arr_avg, 0, [np.average(arr_socket)])
                        print("the average of the array is: " , np.average(arr_socket) , "(filtered outliers)")
                    print("TIME DIFFERENCE SOCKET: " , diff_data_socket* 1000 , "ms")
                    ts_detect_data = ts_detect - ts_data
                    arr_read_vs_detect = np.insert(arr_read_vs_detect, 0, ts_detect_data*1000)
                    print("TIME DIFFERENCE READING IN DATA VS DETECTING FACE" , ts_detect_data*1000)
                    print("the average time between detect and send is: " , np.average(arr_read_vs_detect) , " ms")
                           
                                                  
            # Display the output
            cv2.imshow('frame', frame)
                        

    # Exit if the 'q' key is pressed
    if cv2.waitKey(1) == ord('q'):
        if(socket_ON == True):
            df = pd.DataFrame({'Time socket' : arr_socket, 'Time detect': ts_detect,'Difference (ms)' : diff_data_socket})
            av = pd.DataFrame({'Average' : arr_avg})
            print("socket" , arr_socket)
            print("detect", arr_read_vs_detect)
            # Save DataFrames to Excel file
            with pd.ExcelWriter('output.xlsx') as writer:
                df.to_excel(writer, sheet_name='Timestamps socket')
                av.to_excel(writer, sheet_name='Averages socket')
            
        if(http_request_ON):
            df = pd.DataFrame({'Time http' : arr_http, 'Time detect': ts_detect, 'Difference (ms)' : diff_data_socket})
            av = pd.DataFrame({'Average' : arr_avg})
            print("socket" , diff_ttp)
            print("detect", arr_read_vs_detect)
            # Save DataFrames to Excel file
            with pd.ExcelWriter('output.xlsx') as writer:
                df.to_excel(writer, sheet_name='Timestamps http')
                av.to_excel(writer, sheet_name='Averages http')
            
        
        break
        
    # Remove the processed data from the buffer
    buffer = buffer[b+2:]


# Release the video stream and close the window
cv2.destroyAllWindows()

# %%
import cv2
import urllib.request
import requests
import numpy as np
import socket
from datetime import datetime
import pandas as pd
import time
import http.client
import threading

http.client._MAXHEADERS = 1000

http_request_ON = False
socket_ON = True

#http_request_ON = True
#socket_ON = False

# Load the face detection model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Define the ESP32 Wrover's IP address and port number
url = 'http://10.0.0.15:81'

arr_socket = np.array([])
arr_http = np.array([])
av = pd.DataFrame({})
df = pd.DataFrame({})

# Open the video stream from the ESP32 Wrover
stream = urllib.request.urlopen(url)

cv2.namedWindow('Video Stream', cv2.WINDOW_NORMAL)

def read_data():
    # Read the next frame from the video stream
    buffer = bytes()
    while True:
        try:
            time.sleep(0.001)
            buffer += stream.read(2700)
            #buffer += stream.read(10000)
        except http.client.IncompleteRead:
            print("IncompleteRead error occurred, retrying...")
            continue
    
        a = buffer.find(b'\xff\xd8')
        b = buffer.find(b'\xff\xd9')
        
        
        #print(a, b)
        if a != -1 and b != -1:
            break
        elif a != -1 and b == -1:
            buffer = buffer[a:]
            break
    # Remove the processed data from the buffer
    time.sleep(0.01)
    buffer = buffer[b+2:]
            
def process_data():
    if frame is not None:
            cv2.imshow('Video Stream', frame)

            # Apply the face detection model to the frame
            faces = face_cascade.detectMultiScale(frame, scaleFactor=1.1, minNeighbors=5)
            
            # Draw bounding boxes around the detected faces
            for (x, y, w, h) in faces:
                cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
                
                #SET TIMESTAMP, FACE DETECTED
                dt = datetime.now()
                ts_detect = datetime.timestamp(dt)
                #print("FACE DETECTED ON:", ts_detect)
                
                # Define the ESP32's IP address and port number
                ip = "10.0.0.15"
                port = 81
    
                #print("I see you!")

                # Define the integer to send
                message = 3
                
                if http_request_ON == True :
                    # Send number 32 to ESP32 over WiFi
                    print("sending data over http_request!")
                    #requests.get('http://10.0.0.15/?data=3')
                    try:
                        response = requests.get('http://10.0.0.15/?data=3', timeout=1)
                    except requests.Timeout:
                        print("Request timed out")
        
                    #SET TIMESTAMP HTTP_REQUEST
                    dt = datetime.now()
                    ts_HTTP_REQUEST_data = datetime.timestamp(dt)
                    print("DATA SEND VIA HTTP_REQUEST ON:", ts_HTTP_REQUEST_data)
                    
                    diff_data_HTTPREQUEST =  ts_HTTP_REQUEST_data -ts_detect
                    #if statement groter dan 1 sec niet gebruiken in array.
                    if(diff_data_HTTPREQUEST  < 2):
                        arr_http = np.insert(arr_http, 0, [diff_data_HTTPREQUEST * 1000])
                        #print(arr_http)
                        arr_avg = np.array([])
                        arr_avg = np.insert(arr_avg, 0, [np.average(arr_http)])
                        print("the average of the array is: " , np.average(arr_http) , "(filtered outliers)")
                    print("TIME DIFFERENCE HTTP REQUEST:" , diff_data_HTTPREQUEST * 1000 , "ms") 
                    
                #define staat bovenaan! 
                if socket_ON == True :
                    # Create a socket object
                    #print("sending data over socket!")
                    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

                    # Connect to the ESP32
                    #print("connecting so ESP32")
                    client_socket.connect((ip, port))

                    # Send the integer as a string
                    #print("sending message as a string")
                    client_socket.send(str(message).encode())
                
                    #SET TIMESTAMP SOCKET
                    dt = datetime.now()
                    ts_socket_data = datetime.timestamp(dt)
                    #print("DATA SEND VIA SOCKET ON:", ts_socket_data)

                    # Close the socket connection
                    client_socket.close()
                    
                    diff_data_socket = ts_socket_data - ts_detect
                    if(diff_data_socket  < 1):
                        arr_socket = np.insert(arr_socket, 0, [diff_data_socket * 1000])
                        #print(arr_socket)
                        arr_avg = np.array([])
                        arr_avg = np.insert(arr_avg, 0, [np.average(arr_socket)])
                        print("the average of the array is: " , np.average(arr_socket) , "(filtered outliers)")
                    print("TIME DIFFERENCE SOCKET: " , diff_data_socket* 1000 , "ms")
                           
                                                  
            # Display the output
            cv2.imshow('frame', frame)
            
thread_read = threading.Thread(target = read_data())
thread_process = threading.Thread(target = process_data())
    
thread_read.start()
thread_process.start()
    
thread1.join()
thread2.join()

                        

# Exit if the 'q' key is pressed
if cv2.waitKey(1) == ord('q'):
    if(socket_ON == True):
        df = pd.DataFrame({'Time socket' : arr_socket, 'Time detect': ts_detect,'Difference (ms)' : diff_data_socket})
        av = pd.DataFrame({'Average' : arr_avg})
        # Save DataFrames to Excel file
        with pd.ExcelWriter('output.xlsx') as writer:
            df.to_excel(writer, sheet_name='Timestamps socket')
            av.to_excel(writer, sheet_name='Averages socket')
            
    if(http_request_ON):
        df = pd.DataFrame({'Time http' : arr_http, 'Time detect': ts_detect, 'Difference (ms)' : diff_data_socket})
        av = pd.DataFrame({'Average' : arr_avg})
        # Save DataFrames to Excel file
        with pd.ExcelWriter('output.xlsx') as writer:
            df.to_excel(writer, sheet_name='Timestamps http')
            av.to_excel(writer, sheet_name='Averages http') 
    break
        

# Release the video stream and close the window
cv2.destroyAllWindows()

# %%
#socket pas sluiten bij 'q'
import cv2
import urllib.request
import requests
import numpy as np
import socket
from datetime import datetime
import pandas as pd
import time
import http.client
import os.path
from openpyxl import load_workbook


socket_ON = True
if(socket_ON):
    http_request_ON = False
    socket_ON = True
    filename = "output_socket_memory.xlsx"
else:
    http_request_ON = True
    socket_ON = False
    filename = "output_http_memory.xlsx"
cycles = 0
counter = 1

# Load the face detection model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Define the ESP32 Wrover's IP address and port number
url = 'http://192.168.0.179:81'
#print("FACE DETECTED ON:", ts_detect)
# Define the ESP32's IP address and port number
ip = "192.168.0.179"
port = 80
# Define the integer to send
message = 3

#init
arr_socket = np.array([])
arr_http = np.array([])
arr_read_vs_detect = np.array([])
av = pd.DataFrame({})
df = pd.DataFrame({})
ts_detect = 0
arr_data = np.array([])

# Open the video stream from the ESP32 Wrover
stream = urllib.request.urlopen(url)

cv2.namedWindow('Video Stream', cv2.WINDOW_NORMAL)

# Loop through the frames in the video stream, time stamp nog toevoegen begin read en face detected

while True:
    # Read the next frame from the video stream
    buffer = bytes()
    #set timestamp start reading
    dt = datetime.now()
    ts_data = datetime.timestamp(dt)
    while True:
        try:            
            buffer += stream.read(3000)
            #buffer += stream.read(10000)
        except http.client.IncompleteRead:
            print("IncompleteRead error occurred, retrying...")
            continue
    
        a = buffer.find(b'\xff\xd8')
        b = buffer.find(b'\xff\xd9')
        
        
        #print(a, b)
        if a != -1 and b != -1:
            break
        elif a != -1 and b == -1:
            buffer = buffer[a:]
            break
    
    if a != -1 and b != -1 and b > a:
        #print(a,b)
        frame = cv2.imdecode(np.frombuffer(buffer[a:b+2], dtype=np.uint8), cv2.IMREAD_COLOR)

        if frame is not None:
            cv2.imshow('Video Stream', frame)
           
            # Apply the face detection model to the frame
            faces = face_cascade.detectMultiScale(frame, scaleFactor=1.1, minNeighbors=5)
            
            # Draw bounding boxes around the detected faces
            for (x, y, w, h) in faces:
                cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
                
                #SET TIMESTAMP, FACE DETECTED
                dt = datetime.now()
                ts_detect = datetime.timestamp(dt)
                
                
                if http_request_ON == True :
                    # Send number 32 to ESP32 over WiFi
                    print("\n sending data over http_request!")
                    #requests.get('http://10.0.0.15/?data=3')
                    try:
                        response = requests.get('http://' + ip + '/?data=3', timeout=1)
                    except requests.Timeout:
                        print("Request timed out")
        
                    #SET TIMESTAMP HTTP_REQUEST
                    dt = datetime.now()
                    ts_HTTP_REQUEST_data = datetime.timestamp(dt)
                    print("DATA SEND VIA HTTP_REQUEST ON:", ts_HTTP_REQUEST_data)
                    
                    diff_data_HTTPREQUEST =  ts_HTTP_REQUEST_data -ts_detect
                    #if statement groter dan 1 sec niet gebruiken in array.
                    if(diff_data_HTTPREQUEST  < 1):
                        arr_http = np.insert(arr_http, 0, [diff_data_HTTPREQUEST * 1000])
                        #print(arr_http)
                        arr_avg = np.array([])
                        arr_avg = np.insert(arr_avg, 0, [np.average(arr_http)])
                        print("the average of the array is: " , np.average(arr_http) , "(filtered outliers)")
                    print("TIME DIFFERENCE HTTP REQUEST:" , diff_data_HTTPREQUEST * 1000 , "ms") 
                    ts_detect_data = ts_detect - ts_data
                    arr_read_vs_detect = np.insert(arr_read_vs_detect, 0, ts_detect_data*1000)
                    print("TIME DIFFERENCE READING IN DATA VS DETECTING FACE" , ts_detect_data*1000)
                    print("the average time between detect and send is: " , np.average(arr_read_vs_detect), " ms")
                    
                #define staat bovenaan! 
                if socket_ON == True :
                                      
                    # Create a socket object
                    print("\n sending data over socket!")
                    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

                    # Connect to the ESP32
                    print("connecting so ESP32")
                    client_socket.connect((ip, port))
                    
                    # Send the integer as a string
                    print("sending message as a string")
                    client_socket.send(str(message).encode())
                              
                    #SET TIMESTAMP SOCKET
                    dt = datetime.now()
                    ts_socket_data = datetime.timestamp(dt)
                    #print("DATA SEND VIA SOCKET ON:", ts_socket_data)
                    
                      
                    
                    diff_data_socket = ts_socket_data - ts_detect
                    if(diff_data_socket  < 1):
                        arr_socket = np.insert(arr_socket, 0, [diff_data_socket * 1000])
                        #print(arr_socket)
                        arr_avg = np.array([])
                        arr_avg = np.insert(arr_avg, 0, [np.average(arr_socket)])
                        print("the average of the array is: " , np.average(arr_socket) , "(filtered outliers)")
                    print("TIME DIFFERENCE SOCKET: " , diff_data_socket* 1000 , "ms")
                    ts_detect_data = ts_detect - ts_data
                    arr_read_vs_detect = np.insert(arr_read_vs_detect, 0, ts_detect_data*1000)
                    print("TIME DIFFERENCE READING IN DATA VS DETECTING FACE" , ts_detect_data*1000)
                    print("the average time between detect and send is: " , np.average(arr_read_vs_detect) , " ms")
                    if(diff_data_socket < 1):
                        cycles = cycles + 1
                    #receive data about memory usage
                    
                    #data = client_socket.recv(1024)
                    #print("Data received: " , data.decode())
                    
                    #response = requests.get(url + "?data=3")    
                    #mem_used = float(response.text)
                    #mem_used = int(mem_used)
                    #print(mem_used)
                    #data = int(data.decode())
                    #arr_data = np.insert(arr_data, 0, [data])
                    
                                                  
            # Display the output
            cv2.imshow('frame', frame)
             # Remove the processed data from the buffer
            buffer = buffer[b+2:]            

    # Exit if the 'q' key is pressed
    if cv2.waitKey(1) == ord('q') or cycles == 10:
        if socket_ON:
            df = pd.DataFrame({'Difference socket (ms)' : arr_socket, 'Difference detect' : arr_read_vs_detect})
            print("socket", arr_socket)
            print("detect", arr_read_vs_detect)
    
        # Check if the file exists
        if os.path.isfile(filename):
            with pd.ExcelWriter(filename, engine='openpyxl', mode='a') as writer:
                writer.book = load_workbook(filename)
                if 'Timestamps socket' in writer.book.sheetnames:
                    df.to_excel(writer, sheet_name='Timestamps socket', index=False, startrow=1, header=False, mode='a')
                else:
                    df.to_excel(writer, sheet_name='Timestamps socket', index=False, startrow=0)
        else:
            df.to_excel(filename, sheet_name='Timestamps socket', index=False)


                
            
        if(http_request_ON):
            df = pd.DataFrame({'Time http' : arr_http, 'Time detect': ts_detect, 'Difference (ms)' : arr_socket})
            av = pd.DataFrame({'Average' : arr_avg})
            print("socket" , diff_ttp)
            print("detect", arr_read_vs_detect)
            # Save DataFrames to Excel file
            with pd.ExcelWriter('output_http.xlsx') as writer:
                df.to_excel(writer, sheet_name='Timestamps http')
                av.to_excel(writer, sheet_name='Averages http')
            
        # Close the socket connection
        client_socket.close()
        break
        
   
# Release the video stream and close the window
cv2.destroyAllWindows()
# Out:
#  sending data over socket!
# connecting so ESP32
# sending message as a string
# the average of the array is:  14.509916305541992 (filtered outliers)
# TIME DIFFERENCE SOCKET:  14.509916305541992 ms
# TIME DIFFERENCE READING IN DATA VS DETECTING FACE 27.079105377197266
# the average time between detect and send is:  27.079105377197266  ms
#
#  sending data over socket!
# connecting so ESP32
# sending message as a string
# the average of the array is:  10.381340980529785 (filtered outliers)
# TIME DIFFERENCE SOCKET:  6.252765655517578 ms
# TIME DIFFERENCE READING IN DATA VS DETECTING FACE 43.54405403137207
# the average time between detect and send is:  35.31157970428467  ms
#
#  sending data over socket!
# connecting so ESP32
# sending message as a string
# the average of the array is:  9.781916936238607 (filtered outliers)
# TIME DIFFERENCE SOCKET:  8.58306884765625 ms
# TIME DIFFERENCE READING IN DATA VS DETECTING FACE 28.176069259643555
# the average time between detect and send is:  32.93307622273763  ms
#
#  sending data over socket!
# connecting so ESP32
# sending message as a string
# the average of the array is:  9.912669658660889 (filtered outliers)
# TIME DIFFERENCE SOCKET:  10.304927825927734 ms
# TIME DIFFERENCE READING IN DATA VS DETECTING FACE 31.744003295898438
# the average time between detect and send is:  32.63580799102783  ms
#
#  sending data over socket!
# connecting so ESP32
# sending message as a string
# the average of the array is:  9.736156463623047 (filtered outliers)
# TIME DIFFERENCE SOCKET:  9.03010368347168 ms
# TIME DIFFERENCE READING IN DATA VS DETECTING FACE 63.81988525390625
# the average time between detect and send is:  38.872623443603516  ms
#
#  sending data over socket!
# connecting so ESP32
# sending message as a string
# the average of the array is:  9.600480397542318 (filtered outliers)
# TIME DIFFERENCE SOCKET:  8.922100067138672 ms
# TIME DIFFERENCE READING IN DATA VS DETECTING FACE 25.356054306030273
# the average time between detect and send is:  36.619861920674644  ms
#
#  sending data over socket!
# connecting so ESP32
# sending message as a string
# the average of the array is:  9.485551289149694 (filtered outliers)
# TIME DIFFERENCE SOCKET:  8.795976638793945 ms
# TIME DIFFERENCE READING IN DATA VS DETECTING FACE 28.728961944580078
# the average time between detect and send is:  35.49259049551828  ms
#
#  sending data over socket!
# connecting so ESP32
# sending message as a string
# the average of the array is:  9.309589862823486 (filtered outliers)
# TIME DIFFERENCE SOCKET:  8.077859878540039 ms
# TIME DIFFERENCE READING IN DATA VS DETECTING FACE 39.147138595581055
# the average time between detect and send is:  35.94940900802612  ms
