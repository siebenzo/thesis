# %%
import cv2
import numpy as np
from flask import Flask, Response

app = Flask(__name__)
print("GO FIRE WALL IS OFF")
# Set up OpenCV face detection
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def detect_faces(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
    return frame

# Set up video stream from ESP32
def get_video_stream():
    import socket
    import io
    import struct

    server_socket = socket.socket()
    server_socket.bind(('192.168.0.179', 8000))
    server_socket.listen(0)
    connection = server_socket.accept()[0].makefile('rb')
    try:
        while True:
            # Read the length of the image as a 32-bit unsigned int. If the
            # length is zero, quit the loop
            image_len = struct.unpack('<L', connection.read(struct.calcsize('<L')))[0]
            if not image_len:
                break
            # Construct a stream to hold the image data and read the image
            # data from the connection
            image_stream = io.BytesIO()
            image_stream.write(connection.read(image_len))
            # Rewind the stream, open it as an image with PIL and do some
            # processing on it
            image_stream.seek(0)
            frame = np.frombuffer(image_stream.getvalue(), dtype=np.uint8)
            frame = cv2.imdecode(frame, cv2.IMREAD_COLOR)
            frame = detect_faces(frame)
    finally:
        connection.close()
        server_socket.close()

@app.route('/')
def index():
    return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=8000, debug=False)
# Out:
# GO FIRE WALL IS OFF
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.0.102:8000/ (Press CTRL+C to quit)
# [2023-05-07 19:45:54,404] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:45:54] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:45:55,433] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:45:55] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:45:56,461] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:45:56] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:45:57,503] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:45:57] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:45:58,528] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:45:58] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:45:59,581] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:45:59] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:00,613] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:00] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:01,647] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:01] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:02,673] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:02] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:03,711] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:03] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:04,732] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:04] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:05,756] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:05] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:06,791] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:06] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:07,832] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:07] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:08,868] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:08] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:09,909] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:09] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:10,937] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:10] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:11,974] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:11] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:13,013] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:13] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:14,045] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:14] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:15,070] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:15] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:16,097] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:16] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:17,133] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:17] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:18,167] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:18] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:19,202] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:19] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:20,227] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:20] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:21,262] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:21] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:22,303] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:22] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:23,334] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:23] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:24,354] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:24] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:25,384] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:25] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:26,425] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:26] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:27,458] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:27] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:28,487] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:46:28] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:46:29,523] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
# ...
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:09] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:10,461] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:10] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:11,499] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:11] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:12,536] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:12] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:13,571] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:13] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:14,597] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:14] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:15,627] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:15] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:16,661] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:16] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:17,696] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:17] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:18,721] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:18] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:19,739] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:19] "GET / HTTP/1.1" 500 -
# [2023-05-07 19:51:20,779] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\siebe\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 50, in index
#     return Response(get_video_stream(), mimetype='multipart/x-mixed-replace; boundary=frame')
#   File "C:\Users\siebe\AppData\Local\Temp/ipykernel_6784/3974685647.py", line 24, in get_video_stream
#     server_socket.bind(('192.168.0.179', 8000))
# OSError: [WinError 10049] The requested address is not valid in its context
# 192.168.0.179 - - [07/May/2023 19:51:20] "GET / HTTP/1.1" 500 -
